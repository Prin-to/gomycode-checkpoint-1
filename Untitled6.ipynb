# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as skl
from sklearn.metrics import *
from itertools import chain

# %%
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
print(data.isnull().sum())
print(data.info())
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
# ...

# %% [raw]
# We can notice that there is no null data, and everything is int and floats so no need to preprocess the data =)

# %% [markdown]
# # Data viz

# %%
def plt_corr_mp(df):
    corr = df.corr()
    s , ax = plt.subplots( figsize =( 17 , 17))
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True)
    s = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={'shrink' : .9}, 
        ax=ax, 
        annot = True, 
        annot_kws = {'fontsize' : 12})
    
plt_corr_mp(data)

# %% [markdown]
# No correlation so no biased columns. We can now visualize data !

# %%
norm = data.copy()
norm_cols = norm.columns

for col in norm_cols:
    norm[col] = (norm[col] - norm[col].min())/(norm[col].max() - norm[col].min())

fig, ax = plt.subplots(figsize=(17,12))
norm.plot.box(ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(6, 2, figsize = (30, 45))

norm_deaths = norm[ norm["DEATH_EVENT"] == 1]


for iax, ind in zip(ax, range(0, 12, 2)):
    norm.plot.hist(ax = iax[0], x= "DEATH_EVENT", y = norm_cols[ind])
    norm.plot.hist(ax = iax[1], x= "DEATH_EVENT", y = norm_cols[ind+1])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

#features extraction
x = norm[norm_cols[:-1]]
y = norm[norm_cols[-1]]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0, stratify = y)  #splitting data with test size of 25%

logreg = LogisticRegression()
logreg.fit(x_train, y_train)  
y_pred  = logreg.predict(x_test)    
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.87
